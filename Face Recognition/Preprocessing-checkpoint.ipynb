# %%
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
import torchvision as tv
import torch.nn as nn
import torch.functional as F

# %%
import os
from zipfile import ZipFile
from PIL import Image

# %%
path = 'E:\\Study material\\Models and Datasets\\SIH\\New folder (5)\\Version 1 - C'
data = []
for img in os.listdir(path):
    image = Image.open(os.path.join(path, img))
    image = image.resize([340,255])
    data.append(image)

# %%
transf_to_tensor = tv.transforms.ToTensor()

# %%
t_data = []
for img in data:
    t_data.append(transf_to_tensor(img))

# %%
t_data[0]
# Out:
# tensor([[[0.7961, 0.7961, 0.7961,  ..., 0.7529, 0.7569, 0.7569],
#          [0.8000, 0.8039, 0.8000,  ..., 0.7647, 0.7608, 0.7608],
#          [0.7882, 0.7882, 0.8039,  ..., 0.7647, 0.7608, 0.7569],
#          ...,
#          [0.7059, 0.7059, 0.7020,  ..., 0.0314, 0.0392, 0.0392],
#          [0.7020, 0.6902, 0.7020,  ..., 0.0392, 0.0392, 0.0392],
#          [0.7020, 0.7059, 0.7098,  ..., 0.0431, 0.0431, 0.0471]],
#
#         [[0.7922, 0.7961, 0.7922,  ..., 0.7490, 0.7608, 0.7608],
#          [0.7961, 0.8000, 0.8000,  ..., 0.7608, 0.7647, 0.7647],
#          [0.7843, 0.7843, 0.8000,  ..., 0.7686, 0.7647, 0.7608],
#          ...,
#          [0.7216, 0.7216, 0.7176,  ..., 0.0627, 0.0706, 0.0667],
#          [0.7176, 0.7059, 0.7176,  ..., 0.0627, 0.0706, 0.0706],
#          [0.7059, 0.7098, 0.7137,  ..., 0.0588, 0.0667, 0.0588]],
#
#         [[0.8118, 0.8039, 0.8157,  ..., 0.7725, 0.7765, 0.7765],
#          [0.8196, 0.8196, 0.8314,  ..., 0.7922, 0.7843, 0.7804],
# ...

# %%
plt.imshow(data[2].view([340,255,3]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-54953b82f351> in <module>
# ----> 1 plt.imshow(data[2].view([340,255,3]))
#
# AttributeError: 'Image' object has no attribute 'view'

# %%
plt.imshow(t_data[0].view([255,340,3]))

# %%
class Net(nn.Module):
    def __init__(self):
        super.__init__()
        self.l1
# Out:
# <PIL.Image.Image image mode=RGB size=340x255 at 0x176FCB75208>

# %%
train = pd.read_csv('E:\\Study material\\Models and Datasets\\SIH\\New folder (5)\\facial-keypoints-detection\\training.csv')

# %%
train.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# ...

# %%
t_images = train['Image']

# %%
t_tensors = []
for img in t_images:
    t_tensors.append(transf_to_tensor(img))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-c2864be45cde> in <module>
#       1 t_tensors = []
#       2 for img in t_images:
# ----> 3     t_tensors.append(transf_to_tensor(img))
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, pic)
#      99             Tensor: Converted image.
#     100         """
# --> 101         return F.to_tensor(pic)
#     102
#     103     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in to_tensor(pic)
#      53     """
#      54     if not(_is_pil_image(pic) or _is_numpy(pic)):
# ---> 55         raise TypeError('pic should be PIL Image or ndarray. Got {}'.format(type(pic)))
#      56
#      57     if _is_numpy(pic) and not _is_numpy_image(pic):
#
# TypeError: pic should be PIL Image or ndarray. Got <class 'str'>

# %%
plt.imshow(np.fromstring(t_images[0], dtype = int).reshape([255,255]))
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-9ab808b48180> in <module>
# ----> 1 plt.imshow(np.fromstring(t_images[0], dtype = int).reshape([255,255]))
#
# ValueError: string size must be a multiple of element size
